# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import json

def compress_jsonl(input_file, output_file):
    with open(input_file, 'r') as infile:
        current_json = ""
        for line in infile:
            current_json += line
            try:
                json_obj = json.loads(current_json)
                with open(output_file, 'a') as outfile:
                    outfile.write(json.dumps(json_obj, separators=(',',':')) + '\n')
                current_json = ""
            except json.JSONDecodeError:
                continue
    
compress_jsonl('public/courts_for_gpt.jsonl', 'public/compressed_courts_for_comparing.jsonl')

# %%
df = pd.read_json('public/compressed_courts_for_comparing.jsonl', lines=True)
df
# Out:
#                                            resource_uri       id  \
# 0     https://www.courtlistener.com/api/rest/v4/opin...   103875
# 1     https://www.courtlistener.com/api/rest/v4/opin...  9419386
# 2     https://www.courtlistener.com/api/rest/v4/opin...  9419387
# 3     https://www.courtlistener.com/api/rest/v4/opin...  9419388
# 4     https://www.courtlistener.com/api/rest/v4/opin...  9419389
# ...                                                 ...      ...
# 1124  https://www.courtlistener.com/api/rest/v4/opin...   111375
# 1125  https://www.courtlistener.com/api/rest/v4/opin...  9429952
# 1126  https://www.courtlistener.com/api/rest/v4/opin...  9429953
# 1127  https://www.courtlistener.com/api/rest/v4/opin...   325463
# 1128  https://www.courtlistener.com/api/rest/v4/opin...   778317
#
#                                            absolute_url  cluster_id  \
# 0          /opinion/103875/hirabayashi-v-united-states/      103875
# 1          /opinion/103875/hirabayashi-v-united-states/      103875
# 2          /opinion/103875/hirabayashi-v-united-states/      103875
# 3          /opinion/103875/hirabayashi-v-united-states/      103875
# 4          /opinion/103875/hirabayashi-v-united-states/      103875
# ...                                                 ...         ...
# 1124             /opinion/111375/wayte-v-united-states/      111375
# 1125             /opinion/111375/wayte-v-united-states/      111375
# 1126             /opinion/111375/wayte-v-united-states/      111375
# 1127  /opinion/325463/edward-m-kennedy-v-arthur-f-sa...      325463
# 1128  /opinion/778317/yaser-esam-hamdi-esam-fouad-ha...      778317
#
#                                                 cluster  author_id  \
# 0     https://www.courtlistener.com/api/rest/v4/clus...     3115.0
# 1     https://www.courtlistener.com/api/rest/v4/clus...        NaN
# 2     https://www.courtlistener.com/api/rest/v4/clus...        NaN
# 3     https://www.courtlistener.com/api/rest/v4/clus...        NaN
# 4     https://www.courtlistener.com/api/rest/v4/clus...        NaN
# ...                                                 ...        ...
# 1124  https://www.courtlistener.com/api/rest/v4/clus...     2611.0
# 1125  https://www.courtlistener.com/api/rest/v4/clus...        NaN
# 1126  https://www.courtlistener.com/api/rest/v4/clus...        NaN
# 1127  https://www.courtlistener.com/api/rest/v4/clus...        NaN
# 1128  https://www.courtlistener.com/api/rest/v4/clus...        NaN
#
#                                                  author joined_by  \
# 0     https://www.courtlistener.com/api/rest/v4/peop...        []
# 1                                                  None        []
# 2                                                  None        []
# 3                                                  None        []
# 4                                                  None        []
# ...                                                 ...       ...
# 1124  https://www.courtlistener.com/api/rest/v4/peop...        []
# 1125                                               None        []
# 1126                                               None        []
# 1127                                               None        []
# 1128                                               None        []
#
#                           date_created                     date_modified  ...  \
# 0            2010-04-28T09:54:39-07:00  2022-03-07T14:04:30.030299-08:00  ...
# 1     2023-08-02T15:49:12.921336-07:00  2024-09-05T09:19:04.336904-07:00  ...
# 2     2023-08-02T15:49:12.925749-07:00  2024-09-05T09:19:04.343347-07:00  ...
# 3     2023-08-02T15:49:12.928835-07:00  2024-09-05T09:19:04.347692-07:00  ...
# 4     2023-08-02T15:49:12.931232-07:00  2024-09-05T09:19:04.351779-07:00  ...
# ...                                ...                               ...  ...
# 1124         2010-04-28T10:13:11-07:00  2020-02-21T14:20:41.851606-08:00  ...
# 1125  2023-08-02T16:28:25.101205-07:00  2024-09-05T09:27:34.598379-07:00  ...
# 1126  2023-08-02T16:28:25.107688-07:00  2024-09-05T09:27:34.604233-07:00  ...
# 1127         2011-08-23T01:57:09-07:00  2023-08-04T15:16:01.015475-07:00  ...
# 1128         2012-04-18T06:00:27-07:00  2023-08-05T08:56:17.369629-07:00  ...
#
#      plain_text                                               html  \
# 0                <p class="case_cite">320 U.S. 81</p>\n    <p c...
# 1
# 2
# 3
# 4
# ...         ...                                                ...
# 1124             <p class="case_cite">470 U.S. 598</p>\n    <p ...
# 1125
# 1126
# 1127             <p class="case_cite">511 F.2d 430</p>\n    <p ...
# 1128             <p class="case_cite">296 F.3d 278</p>\n    <p ...
#
#                                             html_lawbox html_columbia  \
# 0     <div>\n<center><b>320 U.S. 81 (1943)</b></cent...
# 1
# 2
# 3
# 4
# ...                                                 ...           ...
# 1124  <div>\n<center><b>470 U.S. 598 (1985)</b></cen...
# 1125
# 1126
# 1127
# 1128
#
#      html_anon_2020                                        xml_harvard  \
# 0
# 1                    <opinion type="majority">\n<author id="b149-3"...
# 2                    <opinion type="concurrence">\n<author id="b171...
# 3                    <opinion type="concurrence">\n<author id="b175...
# 4                    <opinion type="concurrence">\n<author id="b180...
# ...             ...                                                ...
# 1124
# 1125                 <opinion type="majority">\n<author id="AFF1">J...
# 1126                 <opinion type="dissent">\n<author id="b670-8">...
# 1127                 <?xml version="1.0" encoding="utf-8"?>\n<opini...
# 1128                 <?xml version="1.0" encoding="utf-8"?>\n<opini...
#
#                                     html_with_citations extracted_by_ocr  \
# 0     <div>\n<center><b><span class="citation no-lin...            False
# 1                                                                  False
# 2                                                                  False
# 3                                                                  False
# 4                                                                  False
# ...                                                 ...              ...
# 1124  <div>\n<center><b><span class="citation no-lin...            False
# 1125                                                               False
# 1126                                                               False
# 1127  <p class="case_cite"><span class="citation no-...            False
# 1128  <p class="case_cite"><span class="citation no-...            False
#
#      ordering_key                                     opinions_cited
# 0             NaN  [https://www.courtlistener.com/api/rest/v4/opi...
# 1             1.0                                                 []
# 2             2.0                                                 []
# 3             3.0                                                 []
# 4             4.0                                                 []
# ...           ...                                                ...
# 1124          NaN  [https://www.courtlistener.com/api/rest/v4/opi...
# 1125          1.0                                                 []
# 1126          2.0                                                 []
# 1127          NaN  [https://www.courtlistener.com/api/rest/v4/opi...
# 1128          NaN  [https://www.courtlistener.com/api/rest/v4/opi...
#
# [1129 rows x 28 columns]

# %%
((df == "") | df.isnull()).sum().sort_values(ascending=False)
# Out:
# html_anon_2020         1129
# joined_by_str          1129
# html_columbia          1129
# page_count              901
# plain_text              899
# local_path              899
# html                    868
# author_id               846
# author                  846
# html_lawbox             812
# download_url            766
# ordering_key            645
# html_with_citations     484
# sha1                    484
# author_str              394
# xml_harvard             385
# extracted_by_ocr          0
# resource_uri              0
# id                        0
# type                      0
# per_curiam                0
# date_modified             0
# date_created              0
# joined_by                 0
# cluster                   0
# cluster_id                0
# absolute_url              0
# opinions_cited            0
# dtype: int64

# %%
df_xslx = pd.read_excel('public/Presidential Action Judicial Data.xlsx')
df_xslx
# Out:
#                                    Case Name                     Citation  \
# 0                        Hirabayashi v. U.S   320 U.S. 81, 63 S. Ct. 1375
# 1                          U.S. v. Von Clemm                136 F. 2d 968
# 2                          Korematsu v. U.S.   323 U.S. 214 65 S. Ct. 193
# 3                           Wilcox v. Emmons              67 F. Supp. 339
# 4     International Workers Order v. McGrath                 182 F.2d 368
# ...                                      ...                          ...
# 1240                                     NaN                          NaN
# 1241                                     NaN                          NaN
# 1242                                     NaN                          NaN
# 1243                      Kennedy v. Sampson                511 F. 2d 430
# 1244                       Hamdi v. Rumsfeld                296 F. 3d 278
#
#                                                 Case ID  \
# 0     cites:(103875 OR 9419386 OR 9419387 OR 9419388...
# 1                                       cites:(1511621)
# 2     cites:(104040 OR 9419548 OR 9419549 OR 9419550...
# 3                                                   NaN
# 4                  cites:(225161 OR 9442465 OR 9442466)
# ...                                                 ...
# 1240                                             145658
# 1241                                             145749
# 1242                                             237526
# 1243                                             325463
# 1244                                             778317
#
#                                         Specific Action  \
# 0                                      Exec. Order 9066
# 1                                      Exec. Order 8405
# 2                                      Exec. Order 9066
# 3                                      Exec. Order 9066
# 4                                      Exec. Order 9835
# ...                                                 ...
# 1240                                                NaN
# 1241                                                NaN
# 1242                                                NaN
# 1243  Dec 24, 1970 President issued memorandum of di...
# 1244  Authorization for Use of Military Force follow...
#
#      Decision For President     AI Match? Revised Matches Unnamed: 7
# 0                       NaN           NaN             NaN        NaN
# 1                       For           NaN             NaN        NaN
# 2                       NaN           NaN             NaN        NaN
# 3                       NaN           NaN             NaN        NaN
# 4                       For  Unfavourable       Favorable        NaN
# ...                     ...           ...             ...        ...
# 1240                    NaN           NaN             NaN        NaN
# 1241                    NaN           NaN             NaN        NaN
# 1242                    NaN           NaN             NaN        NaN
# 1243                    NaN           NaN             NaN        NaN
# 1244                    NaN           NaN             NaN        NaN
#
# [1245 rows x 8 columns]

# %%
df_xslx.columns
# Out:
# Index(['Case Name', 'Citation', 'Case ID', 'Specific Action',
#        'Decision For President', 'AI Match?', 'Revised Matches', 'Unnamed: 7'],
#       dtype='object')

# %%
import re

df['id'] = df['id'].astype(str)
df_xslx['Case ID'] = df_xslx['Case ID'].astype(str)

def extract_ids(case_id):
    matches = re.findall(r'\d+', case_id)
    return matches  

decision_dict = {}
for _, row in df_xslx.iterrows():
    case_ids = extract_ids(row['Case ID']) 
    for case_id in case_ids:
        decision_dict[case_id] = row['Decision For President']

df['Decision For President'] = df['id'].map(decision_dict).fillna(np.nan)

df.head()
# Out:
#                                         resource_uri       id  \
# 0  https://www.courtlistener.com/api/rest/v4/opin...   103875
# 1  https://www.courtlistener.com/api/rest/v4/opin...  9419386
# 2  https://www.courtlistener.com/api/rest/v4/opin...  9419387
# 3  https://www.courtlistener.com/api/rest/v4/opin...  9419388
# 4  https://www.courtlistener.com/api/rest/v4/opin...  9419389
#
#                                    absolute_url  cluster_id  \
# 0  /opinion/103875/hirabayashi-v-united-states/      103875
# 1  /opinion/103875/hirabayashi-v-united-states/      103875
# 2  /opinion/103875/hirabayashi-v-united-states/      103875
# 3  /opinion/103875/hirabayashi-v-united-states/      103875
# 4  /opinion/103875/hirabayashi-v-united-states/      103875
#
#                                              cluster  author_id  \
# 0  https://www.courtlistener.com/api/rest/v4/clus...     3115.0
# 1  https://www.courtlistener.com/api/rest/v4/clus...        NaN
# 2  https://www.courtlistener.com/api/rest/v4/clus...        NaN
# 3  https://www.courtlistener.com/api/rest/v4/clus...        NaN
# 4  https://www.courtlistener.com/api/rest/v4/clus...        NaN
#
#                                               author joined_by  \
# 0  https://www.courtlistener.com/api/rest/v4/peop...        []
# 1                                               None        []
# 2                                               None        []
# 3                                               None        []
# 4                                               None        []
#
#                        date_created                     date_modified  ...  \
# 0         2010-04-28T09:54:39-07:00  2022-03-07T14:04:30.030299-08:00  ...
# 1  2023-08-02T15:49:12.921336-07:00  2024-09-05T09:19:04.336904-07:00  ...
# 2  2023-08-02T15:49:12.925749-07:00  2024-09-05T09:19:04.343347-07:00  ...
# 3  2023-08-02T15:49:12.928835-07:00  2024-09-05T09:19:04.347692-07:00  ...
# 4  2023-08-02T15:49:12.931232-07:00  2024-09-05T09:19:04.351779-07:00  ...
#
#                                                 html  \
# 0  <p class="case_cite">320 U.S. 81</p>\n    <p c...
# 1
# 2
# 3
# 4
#
#                                          html_lawbox html_columbia  \
# 0  <div>\n<center><b>320 U.S. 81 (1943)</b></cent...
# 1
# 2
# 3
# 4
#
#   html_anon_2020                                        xml_harvard  \
# 0
# 1                 <opinion type="majority">\n<author id="b149-3"...
# 2                 <opinion type="concurrence">\n<author id="b171...
# 3                 <opinion type="concurrence">\n<author id="b175...
# 4                 <opinion type="concurrence">\n<author id="b180...
#
#                                  html_with_citations extracted_by_ocr  \
# 0  <div>\n<center><b><span class="citation no-lin...            False
# 1                                                               False
# 2                                                               False
# 3                                                               False
# 4                                                               False
#
#   ordering_key                                     opinions_cited  \
# 0          NaN  [https://www.courtlistener.com/api/rest/v4/opi...
# 1          1.0                                                 []
# 2          2.0                                                 []
# 3          3.0                                                 []
# 4          4.0                                                 []
#
#   Decision For President
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 29 columns]

# %%
df_sorted = df.sort_values(by='Decision For President', ascending=False, na_position='last')
print(df_sorted['Decision For President'].notnull().sum())
print(df_sorted['Decision For President'].isnull().sum())
df_sorted
# Out:
# 148
# 981
#                                            resource_uri       id  \
# 5     https://www.courtlistener.com/api/rest/v4/opin...  1511621
# 664   https://www.courtlistener.com/api/rest/v4/opin...  9439564
# 843   https://www.courtlistener.com/api/rest/v4/opin...   781274
# 819   https://www.courtlistener.com/api/rest/v4/opin...  2453197
# 815   https://www.courtlistener.com/api/rest/v4/opin...  2312256
# ...                                                 ...      ...
# 1124  https://www.courtlistener.com/api/rest/v4/opin...   111375
# 1125  https://www.courtlistener.com/api/rest/v4/opin...  9429952
# 1126  https://www.courtlistener.com/api/rest/v4/opin...  9429953
# 1127  https://www.courtlistener.com/api/rest/v4/opin...   325463
# 1128  https://www.courtlistener.com/api/rest/v4/opin...   778317
#
#                                            absolute_url  cluster_id  \
# 5           /opinion/1511621/united-states-v-von-clemm/     1511621
# 664   /opinion/186848/boumediene-lakhdar-v-bush-george/      186848
# 843   /opinion/781274/john-doe-i-john-doe-ii-john-do...      781274
# 819                     /opinion/2453197/newdow-v-bush/     2453197
# 815   /opinion/2312256/in-re-agent-orange-product-li...     2312256
# ...                                                 ...         ...
# 1124             /opinion/111375/wayte-v-united-states/      111375
# 1125             /opinion/111375/wayte-v-united-states/      111375
# 1126             /opinion/111375/wayte-v-united-states/      111375
# 1127  /opinion/325463/edward-m-kennedy-v-arthur-f-sa...      325463
# 1128  /opinion/778317/yaser-esam-hamdi-esam-fouad-ha...      778317
#
#                                                 cluster  author_id  \
# 5     https://www.courtlistener.com/api/rest/v4/clus...        NaN
# 664   https://www.courtlistener.com/api/rest/v4/clus...        NaN
# 843   https://www.courtlistener.com/api/rest/v4/clus...        NaN
# 819   https://www.courtlistener.com/api/rest/v4/clus...      201.0
# 815   https://www.courtlistener.com/api/rest/v4/clus...     3414.0
# ...                                                 ...        ...
# 1124  https://www.courtlistener.com/api/rest/v4/clus...     2611.0
# 1125  https://www.courtlistener.com/api/rest/v4/clus...        NaN
# 1126  https://www.courtlistener.com/api/rest/v4/clus...        NaN
# 1127  https://www.courtlistener.com/api/rest/v4/clus...        NaN
# 1128  https://www.courtlistener.com/api/rest/v4/clus...        NaN
#
#                                                  author joined_by  \
# 5                                                  None        []
# 664                                                None        []
# 843                                                None        []
# 819   https://www.courtlistener.com/api/rest/v4/peop...        []
# 815   https://www.courtlistener.com/api/rest/v4/peop...        []
# ...                                                 ...       ...
# 1124  https://www.courtlistener.com/api/rest/v4/peop...        []
# 1125                                               None        []
# 1126                                               None        []
# 1127                                               None        []
# 1128                                               None        []
#
#                           date_created                     date_modified  ...  \
# 5     2013-10-29T23:31:45.104529-07:00  2023-08-22T13:55:16.009358-07:00  ...
# 664   2023-08-02T23:39:19.592143-07:00  2024-09-05T09:35:06.533874-07:00  ...
# 843          2012-04-18T08:29:35-07:00  2022-03-07T23:19:16.761932-08:00  ...
# 819   2013-10-30T02:39:25.173195-07:00  2023-08-29T12:21:01.280518-07:00  ...
# 815   2013-10-30T02:03:34.856028-07:00  2022-03-08T12:29:11.102377-08:00  ...
# ...                                ...                               ...  ...
# 1124         2010-04-28T10:13:11-07:00  2020-02-21T14:20:41.851606-08:00  ...
# 1125  2023-08-02T16:28:25.101205-07:00  2024-09-05T09:27:34.598379-07:00  ...
# 1126  2023-08-02T16:28:25.107688-07:00  2024-09-05T09:27:34.604233-07:00  ...
# 1127         2011-08-23T01:57:09-07:00  2023-08-04T15:16:01.015475-07:00  ...
# 1128         2012-04-18T06:00:27-07:00  2023-08-05T08:56:17.369629-07:00  ...
#
#                                                    html  \
# 5
# 664
# 843   <p class="case_cite">323 F.3d 133</p>\n    <p ...
# 819
# 815
# ...                                                 ...
# 1124  <p class="case_cite">470 U.S. 598</p>\n    <p ...
# 1125
# 1126
# 1127  <p class="case_cite">511 F.2d 430</p>\n    <p ...
# 1128  <p class="case_cite">296 F.3d 278</p>\n    <p ...
#
#                                             html_lawbox html_columbia  \
# 5     <div>\n<center><b>136 F.2d 968 (1943)</b></cen...
# 664
# 843
# 819   <div>\n<center><b>355 F.Supp.2d 265 (2005)</b>...
# 815   <div>\n<center><b>373 F.Supp.2d 7 (2005)</b></...
# ...                                                 ...           ...
# 1124  <div>\n<center><b>470 U.S. 598 (1985)</b></cen...
# 1125
# 1126
# 1127
# 1128
#
#      html_anon_2020                                        xml_harvard  \
# 5                    <?xml version="1.0" encoding="utf-8"?>\n<opini...
# 664                  <opinion type="dissent">\n<author id="b1024-12...
# 843
# 819                  <?xml version="1.0" encoding="utf-8"?>\n<opini...
# 815
# ...             ...                                                ...
# 1124
# 1125                 <opinion type="majority">\n<author id="AFF1">J...
# 1126                 <opinion type="dissent">\n<author id="b670-8">...
# 1127                 <?xml version="1.0" encoding="utf-8"?>\n<opini...
# 1128                 <?xml version="1.0" encoding="utf-8"?>\n<opini...
#
#                                     html_with_citations extracted_by_ocr  \
# 5     <div>\n<center><b><span class="citation no-lin...            False
# 664                                                                False
# 843   <p class="case_cite"><span class="citation no-...            False
# 819   <div>\n<center><b><span class="citation no-lin...            False
# 815   <div>\n<center><b><span class="citation no-lin...            False
# ...                                                 ...              ...
# 1124  <div>\n<center><b><span class="citation no-lin...            False
# 1125                                                               False
# 1126                                                               False
# 1127  <p class="case_cite"><span class="citation no-...            False
# 1128  <p class="case_cite"><span class="citation no-...            False
#
#      ordering_key                                     opinions_cited  \
# 5             NaN  [https://www.courtlistener.com/api/rest/v4/opi...
# 664           2.0                                                 []
# 843           NaN  [https://www.courtlistener.com/api/rest/v4/opi...
# 819           NaN  [https://www.courtlistener.com/api/rest/v4/opi...
# 815           NaN  [https://www.courtlistener.com/api/rest/v4/opi...
# ...           ...                                                ...
# 1124          NaN  [https://www.courtlistener.com/api/rest/v4/opi...
# 1125          1.0                                                 []
# 1126          2.0                                                 []
# 1127          NaN  [https://www.courtlistener.com/api/rest/v4/opi...
# 1128          NaN  [https://www.courtlistener.com/api/rest/v4/opi...
#
#      Decision For President
# 5                       For
# 664                     For
# 843                     For
# 819                     For
# 815                     For
# ...                     ...
# 1124                    NaN
# 1125                    NaN
# 1126                    NaN
# 1127                    NaN
# 1128                    NaN
#
# [1129 rows x 29 columns]

# %%
import json

def create_batch_4o_mini(custom_id, method, url, messages, output_file):
    batch_entry = {
        "custom_id": custom_id,
        "method": method,
        "url": url,
        "body": {
            "model": "gpt-4o-mini",
            "messages": messages,
            "max_tokens": 9000
        }
    }
    with open(output_file, 'a') as outfile:
        outfile.write(json.dumps(batch_entry, separators=(',',':')) + '\n')

def create_batch_4o(custom_id, method, url, messages, output_file):
    batch_entry = {
        "custom_id": custom_id,
        "method": method,
        "url": url,
        "body": {
            "model": "gpt-4o",
            "messages": messages,
            "max_tokens": 9000
        }
    }
    with open(output_file, 'a') as outfile:
        outfile.write(json.dumps(batch_entry, separators=(',',':')) + '\n')
        
output_file_4o_mini = 'public/batch_input_4o_mini.jsonl'
output_file_4o = 'public/batch_input_4o.jsonl'
method = "POST"
url = "/v1/chat/completions"

line_count = 0
for index, row in df_sorted.iterrows():
    if line_count >= 148:  # Limit to first 148 lines
        break
    valid_column = next(
        (col for col in ['html', 'xml_harvard', 'plain_text', 'html_lawbox'] if pd.notnull(row[col]) and row[col] != ""), 
        None
    )

    custom_id = f"request-{index + 1}"
    messages = [
    {
        "role": "system", 
        "content": "Your goal is to determine whether each opinion is in favor of or opposing the President. You will receive the text of a Supreme Court opinion, and you should analyze the sentiment and key phrases to make your determination."
    },
    {
        "role": "user", 
        "content": f"""Here is the text of a Supreme Court opinion: {row[valid_column]}.
        Based on this opinion, please analyze the sentiment and determine if it is in favor of or opposing the President. 
        Return your response in JSON format:
            {{
                "resource": "{row['resource_uri']}",
                "opinion": "with values 'in favor' or 'opposed'",
                "explanation": "a brief explanation of your conclusion"
            }}
        """
    }
]

    create_batch_4o_mini(custom_id, method, url, messages, output_file_4o_mini)
    create_batch_4o(custom_id, method, url, messages, output_file_4o)
    line_count += 1  # Increment line count

# %%
import tiktoken
import json

def count_tokens_in_line(json_line, model_name='gpt-4'):
    if isinstance(json_line, dict):
        json_str = json.dumps(json_line)
    else:
        json_str = json_line

    encoding = tiktoken.encoding_for_model(model_name)
    tokens = encoding.encode(json_str)
    return len(tokens)

line = '{"id": "example", "name": "This is a sample entry for checking token count."}'
token_count = count_tokens_in_line(line)

print(f"Token count for the line: {token_count}")
# Out:
# Token count for the line: 21

# %%
import os

def test(input_file, output_files, num):
    with open(input_file, 'r') as infile:
        line_count = 0 
        for line in infile:
            if line_count >= 148: 
                break
            try:
                if count_tokens_in_line(line) > 128000: 
                    print("Line exceeds the token limit and will be skipped.")
                    line_count += 1
                    continue
                json_obj = json.loads(line)
                output_index = line_count // num
                os.makedirs(os.path.dirname(output_files[output_index]), exist_ok=True)
                with open(output_files[output_index], 'a') as outfile:
                    outfile.write(json.dumps(json_obj) + '\n')
            except json.JSONDecodeError:
                continue
            line_count += 1  

mini_files = [f'public/4o_mini/{i}_mini.jsonl' for i in range(1, 3)]
test('public/batch_input_4o_mini.jsonl', mini_files, 74)

full_files = [f'public/4o/{i}.jsonl' for i in range(1, 16)]
test('public/batch_input_4o.jsonl', full_files, 10)
# Out:
# Line exceeds the token limit and will be skipped.
# Line exceeds the token limit and will be skipped.

# %%
import time
from dotenv import load_dotenv
load_dotenv()

from openai import OpenAI, RateLimitError, APIError
client = OpenAI()

def cancel_all_batches():
    try:
        batches = client.batches.list()
        for batch in batches:
            cancellable_statuses = ["queued", "in_progress"]
            if batch.status in cancellable_statuses:
                client.batches.cancel(batch.id)
            wait_for_cancel(batch.id)
    except APIError as e:
        print(f"API Error while cancelling batches: {str(e)}")
    except Exception as ex:
        print(f"Unexpected error while cancelling batches: {str(ex)}")

def wait_for_cancel(batch_id, timeout=60):
    start_time = time.time()
    while time.time() - start_time < timeout:
        try:
            batch = client.batches.retrieve(batch_id)
            if batch.status == "cancelled":
                print(f"Batch {batch_id} successfully canceled.")
                return
            elif batch.status in ["failed", "completed"]:
                print(f"Batch {batch_id} has status {batch.status}.")
                return
            else:
                print(f"Waiting for batch {batch_id} to cancel. Current status: {batch.status}")
        except APIError as e:
            print(f"API Error while checking batch status: {str(e)}")
            break
        time.sleep(5)
    print(f"Timeout reached while waiting for batch {batch_id} to cancel.")
    
# Stop previous batches (Optional)
# cancel_all_batches()

# %%
def process_files(files_to_process, file_ids, batch_ids, pause = 10):
    for file in files_to_process:
        try:
          batch_input_file = client.files.create(
            file=open(file, "rb"),
            purpose="batch"
          )

          batch_input_file_id = batch_input_file.id
          file_ids.append(batch_input_file_id)

          batch = client.batches.create(
              input_file_id=batch_input_file_id,
              endpoint="/v1/chat/completions",
              completion_window="24h",
              metadata={
                "description": f"test job for {file}"
              }
          )
          batch_ids.append(batch.id)

        except RateLimitError as e:
          print(f"RateLimitError Error for {file}: {str(e)}")
        except APIError as e:
            print(f"OpenAI Error for {file}: {str(e)}")
        except Exception as ex:
            print(f"Unexpected error: {str(ex)}")
        time.sleep(pause)

file_ids_4o = []
batch_ids_4o = []
process_files(full_files, file_ids_4o, batch_ids_4o)

file_ids_4o_mini = []
batch_ids_4o_mini = []
process_files(mini_files, file_ids_4o_mini, batch_ids_4o_mini)

# %%
def check_batch(batch_ids):
    res = {}
    for batch_id in batch_ids:
        try:
            print(client.batches.retrieve(batch_id))
        except Exception as e:
            print(f"Error retrieving status: {e}")
    
check_batch(batch_ids_4o_mini)
check_batch(batch_ids_4o)
# Out:
# Batch(id='batch_672218c11a0c8190b6dc8cb293aa142f', completion_window='24h', created_at=1730287809, endpoint='/v1/chat/completions', input_file_id='file-CTebQyaa9vxtgoXjdq69JqU7', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1730287836, error_file_id=None, errors=None, expired_at=None, expires_at=1730374209, failed_at=None, finalizing_at=1730287831, in_progress_at=1730287809, metadata={'description': 'test job for public/4o_mini/1_mini.jsonl'}, output_file_id='file-6cFcby3CHnp2x2dwEFjEx3xE', request_counts=BatchRequestCounts(completed=74, failed=0, total=74))
# Batch(id='batch_67221924b96c8190953c143af646e128', completion_window='24h', created_at=1730287908, endpoint='/v1/chat/completions', input_file_id='file-yUKfltOYNxNbz5Lxb19UuApg', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1730287944, error_file_id=None, errors=None, expired_at=None, expires_at=1730374308, failed_at=None, finalizing_at=1730287939, in_progress_at=1730287909, metadata={'description': 'test job for public/4o_mini/2_mini.jsonl'}, output_file_id='file-5ROetssmAjiGy4NTKy1aXz0t', request_counts=BatchRequestCounts(completed=73, failed=0, total=73))
# Batch(id='batch_6722179b5fdc8190a11f55000778a41c', completion_window='24h', created_at=1730287515, endpoint='/v1/chat/completions', input_file_id='file-JsFd91Ip54jBxsh3cfAjQp3r', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1730287540, error_file_id=None, errors=None, expired_at=None, expires_at=1730373915, failed_at=None, finalizing_at=1730287539, in_progress_at=1730287515, metadata={'description': 'test job for public/4o/1.jsonl'}, output_file_id='file-Vq7BPba70QBl8QAeDPuuI6Bv', request_counts=BatchRequestCounts(completed=10, failed=0, total=10))
# Batch(id='batch_672217ae35a4819088ec824ed67b6716', completion_window='24h', created_at=1730287534, endpoint='/v1/chat/completions', input_file_id='file-J06QrG6N0n9l5jCDkKssIFrb', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1730287564, error_file_id=None, errors=None, expired_at=None, expires_at=1730373934, failed_at=None, finalizing_at=1730287563, in_progress_at=1730287534, metadata={'description': 'test job for public/4o/2.jsonl'}, output_file_id='file-V1gTMHpQmhSHTsIOIEsM0Bof', request_counts=BatchRequestCounts(completed=10, failed=0, total=10))
# Batch(id='batch_672217bb6d188190b978741e2873fa37', completion_window='24h', created_at=1730287547, endpoint='/v1/chat/completions', input_file_id='file-hWxkLIXbZf1t1177M9c7nBhG', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1730287561, error_file_id=None, errors=None, expired_at=None, expires_at=1730373947, failed_at=None, finalizing_at=1730287560, in_progress_at=1730287547, metadata={'description': 'test job for public/4o/3.jsonl'}, output_file_id='file-JBfTqc7GBPGQPxuKnQGCtL09', request_counts=BatchRequestCounts(completed=10, failed=0, total=10))
# Batch(id='batch_672217c96f3081909560d1acfcbedce0', completion_window='24h', created_at=1730287561, endpoint='/v1/chat/completions', input_file_id='file-x2x18B8S3EFzv7jiOcbUaEd1', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1730287579, error_file_id=None, errors=None, expired_at=None, expires_at=1730373961, failed_at=None, finalizing_at=1730287578, in_progress_at=1730287561, metadata={'description': 'test job for public/4o/4.jsonl'}, output_file_id='file-NorF7QzaKOBFxYHJ67zPOv8H', request_counts=BatchRequestCounts(completed=10, failed=0, total=10))
# Batch(id='batch_672217d656748190b337eac66dd38266', completion_window='24h', created_at=1730287574, endpoint='/v1/chat/completions', input_file_id='file-ll8vngwF6rHE99SgMsR77XPw', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1730287590, error_file_id=None, errors=None, expired_at=None, expires_at=1730373974, failed_at=None, finalizing_at=1730287588, in_progress_at=1730287574, metadata={'description': 'test job for public/4o/5.jsonl'}, output_file_id='file-kPdOSSQ1YbQM0G4AiJslzwps', request_counts=BatchRequestCounts(completed=10, failed=0, total=10))
# Batch(id='batch_672217e3be7c8190a6c90e3e7e67e2ca', completion_window='24h', created_at=1730287587, endpoint='/v1/chat/completions', input_file_id='file-sIcgyIcvfXBYjhrIUc7eajLA', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1730287630, error_file_id=None, errors=None, expired_at=None, expires_at=1730373987, failed_at=None, finalizing_at=1730287629, in_progress_at=1730287588, metadata={'description': 'test job for public/4o/6.jsonl'}, output_file_id='file-vf49llmF0al3CBmUYv12wIlv', request_counts=BatchRequestCounts(completed=10, failed=0, total=10))
# Batch(id='batch_672217f772b88190a52e86ee38a6e865', completion_window='24h', created_at=1730287607, endpoint='/v1/chat/completions', input_file_id='file-YSgEfX2TBA83RmW6aTy6Z3we', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1730287698, error_file_id=None, errors=None, expired_at=None, expires_at=1730374007, failed_at=None, finalizing_at=1730287697, in_progress_at=1730287667, metadata={'description': 'test job for public/4o/7.jsonl'}, output_file_id='file-UvzRMFrOL4PXNtYdThyS2kyO', request_counts=BatchRequestCounts(completed=10, failed=0, total=10))
# Batch(id='batch_67221803ce7081909b9b0917b145a143', completion_window='24h', created_at=1730287620, endpoint='/v1/chat/completions', input_file_id='file-MwGHUGEVAqqGYyFPtl9mWnS8', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1730287634, error_file_id=None, errors=None, expired_at=None, expires_at=1730374020, failed_at=None, finalizing_at=1730287632, in_progress_at=1730287620, metadata={'description': 'test job for public/4o/8.jsonl'}, output_file_id='file-Ts8U6lo2Jpbe8QwEr03T6KJS', request_counts=BatchRequestCounts(completed=10, failed=0, total=10))
# Batch(id='batch_67221811037881908b54278498dd927d', completion_window='24h', created_at=1730287633, endpoint='/v1/chat/completions', input_file_id='file-GpJqf6WNAQcWOY1D674PHCGU', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1730287644, error_file_id=None, errors=None, expired_at=None, expires_at=1730374033, failed_at=None, finalizing_at=1730287643, in_progress_at=1730287633, metadata={'description': 'test job for public/4o/9.jsonl'}, output_file_id='file-MihU7gFMtCZyIcuheFeD7FjI', request_counts=BatchRequestCounts(completed=10, failed=0, total=10))
# Batch(id='batch_6722181fab64819086c8e69ac3d481e4', completion_window='24h', created_at=1730287647, endpoint='/v1/chat/completions', input_file_id='file-1P4j0fHldXVkWuUaWeDHJVva', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1730287732, error_file_id=None, errors=None, expired_at=None, expires_at=1730374047, failed_at=None, finalizing_at=1730287671, in_progress_at=1730287647, metadata={'description': 'test job for public/4o/10.jsonl'}, output_file_id='file-gZf0J1amGT00GqYDFF7zEoij', request_counts=BatchRequestCounts(completed=10, failed=0, total=10))
# Batch(id='batch_67221832284881908dc8cc24941811fd', completion_window='24h', created_at=1730287666, endpoint='/v1/chat/completions', input_file_id='file-Gs3zbN7IxPEYGuLJBWvtQtnr', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1730287695, error_file_id=None, errors=None, expired_at=None, expires_at=1730374066, failed_at=None, finalizing_at=1730287694, in_progress_at=1730287666, metadata={'description': 'test job for public/4o/11.jsonl'}, output_file_id='file-tVM4k0RZbOjNK32XbXJqDOsX', request_counts=BatchRequestCounts(completed=10, failed=0, total=10))
# Batch(id='batch_6722183f4cc881909a23b21b1e216017', completion_window='24h', created_at=1730287679, endpoint='/v1/chat/completions', input_file_id='file-uuWJsFmLDkDfxvSwoSkwwWsk', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1730287691, error_file_id=None, errors=None, expired_at=None, expires_at=1730374079, failed_at=None, finalizing_at=1730287690, in_progress_at=1730287679, metadata={'description': 'test job for public/4o/12.jsonl'}, output_file_id='file-bmd2UhFoEGqHMgjfqpJXhLqk', request_counts=BatchRequestCounts(completed=10, failed=0, total=10))
# Batch(id='batch_6722184dde0c81909b0a7faeb0cc7534', completion_window='24h', created_at=1730287693, endpoint='/v1/chat/completions', input_file_id='file-ND6SloRQDegUUy7M580W6aQm', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1730287726, error_file_id=None, errors=None, expired_at=None, expires_at=1730374093, failed_at=None, finalizing_at=1730287725, in_progress_at=1730287694, metadata={'description': 'test job for public/4o/13.jsonl'}, output_file_id='file-s9MWOsUSRBhcR6k9TsnP48pu', request_counts=BatchRequestCounts(completed=10, failed=0, total=10))
# Batch(id='batch_6722185a88d08190bf64c80d51bdc4bd', completion_window='24h', created_at=1730287706, endpoint='/v1/chat/completions', input_file_id='file-yJgu7FU6j1fbFFsFL6lp4DAR', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1730287722, error_file_id=None, errors=None, expired_at=None, expires_at=1730374106, failed_at=None, finalizing_at=1730287721, in_progress_at=1730287706, metadata={'description': 'test job for public/4o/14.jsonl'}, output_file_id='file-zSczEJwFpqbd3j9OFaJaTPF6', request_counts=BatchRequestCounts(completed=10, failed=0, total=10))
# Batch(id='batch_6722186e58a48190a241f4c18e5b42e8', completion_window='24h', created_at=1730287726, endpoint='/v1/chat/completions', input_file_id='file-hCx7GNyhEw0Qtam6RLPtWBaw', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1730287735, error_file_id=None, errors=None, expired_at=None, expires_at=1730374126, failed_at=None, finalizing_at=1730287735, in_progress_at=1730287726, metadata={'description': 'test job for public/4o/15.jsonl'}, output_file_id='file-R7sycPzmNOgxQQyguW86T3kT', request_counts=BatchRequestCounts(completed=7, failed=0, total=7))

# %%
import json

def content_jsonl(input_file, output_file):
            with open(input_file, 'r') as infile:
                for line in infile:
                    try:
                        json_obj = json.loads(line) 
                        content = json_obj.get('response', {}).get('body', {}).get('choices', [{}])[0].get('message', {}).get('content', '') 
                        with open(output_file, 'a') as outfile:
                            outfile.write(json.dumps(content) + '\n')
                    except json.JSONDecodeError:
                        continue

def retrieve_batches(batch_ids, output_jsonl_file, content_output_file):
    for batch_id in batch_ids:
        batch_info = client.batches.retrieve(batch_id)

        input_file_response = client.files.content(batch_info.output_file_id)

        for line in input_file_response.text.splitlines():
            try:
                json_obj = json.loads(line)  
                with open(output_jsonl_file, 'a') as outfile:
                    outfile.write(json.dumps(json_obj) + '\n')  
            except json.JSONDecodeError:
                continue
    content_jsonl(output_jsonl_file, content_output_file)

retrieve_batches(batch_ids_4o_mini, 'public/response_test_4o_mini.jsonl', 'public/content_test_4o_mini.jsonl')
retrieve_batches(batch_ids_4o, 'public/response_test_4o.jsonl', 'public/content_test_4o.jsonl')

# %%
import json
import re

def clean_json(input_file, output_file):
    with open(input_file, 'r') as infile, open(output_file, 'w') as outfile:
        for line_number, line in enumerate(infile, start=1):
            line = line.strip()
            
            if not line:
                continue
            
            if line.startswith('"```json\\n') and line.endswith('```"'):
                line = line[10:-3].strip()
            elif line.startswith('"```json\\n') and line.endswith('``` "'):
                line = line[10:-4].strip()
            
            line = line.replace('\\"', '"').replace('\\n', '')[:-1]

            if line.startswith('"'):
                line = line[1:]
            
            line = re.sub(r'\s+(?=(?:[^"]|"[^"]*")*$)', '', line)
            
            try:
                json_obj = json.loads(line)
                outfile.write(json.dumps(json_obj) + '\n')
            except json.JSONDecodeError as e:
                print(e)

# Usage
clean_json('public/content_test_4o_mini.jsonl', 'public/cleaned_content_test_4o_mini.jsonl')
clean_json('public/content_test_4o.jsonl', 'public/cleaned_content_test_4o.jsonl')

# %%
df_4o_mini = pd.read_json('public/cleaned_content_test_4o_mini.jsonl', lines=True)
df_4o = pd.read_json('public/cleaned_content_test_4o.jsonl', lines=True)

# %%
df_4o.replace(['neutral'], np.nan, inplace=True)
df_4o_mini.replace(['neutral'], np.nan, inplace=True)

mode_value = df_4o['opinion'].mode(dropna=True)[0]
df_4o['opinion'] = df_4o['opinion'].fillna(mode_value)
print(df_4o.isnull().sum().sort_values(ascending=False))

mode_value = df_4o_mini['opinion'].mode(dropna=True)[0]
df_4o_mini['opinion'] = df_4o_mini['opinion'].fillna(mode_value)

print(df_4o_mini.isnull().sum().sort_values(ascending=False))
# Out:
# resource       0
# opinion        0
# explanation    0
# dtype: int64
# resource       0
# opinion        0
# explanation    0
# dtype: int64

# %%
def create_id(df):
    df['id'] = df['resource'].str.extract(r'/opinions/(\d+)/\?format=json')[0]

create_id(df_4o)
create_id(df_4o_mini)

# %%
df_4o_mini = df_4o_mini[['id'] + [col for col in df_4o_mini.columns if col != 'id']]
df_4o_mini['model'] = '4o mini'
df_4o = df_4o[['id'] + [col for col in df_4o.columns if col != 'id']]
df_4o['model'] = '4o'

df_4o_mini.head()
# Out:
#         id                                           resource   opinion  \
# 0  1511621  https://www.courtlistener.com/api/rest/v4/opin...  in favor
# 1  9439564  https://www.courtlistener.com/api/rest/v4/opin...   opposed
# 2   781274  https://www.courtlistener.com/api/rest/v4/opin...  in favor
# 3  2453197  https://www.courtlistener.com/api/rest/v4/opin...  in favor
# 4  2312256  https://www.courtlistener.com/api/rest/v4/opin...   opposed
#
#                                          explanation    model
# 0  The court upheld the constitutionality of the ...  4o mini
# 1  The dissenting opinion expresses strong disagr...  4o mini
# 2  The court's ruling affirms the dismissal of th...  4o mini
# 3  The court denied Newdow's motion for a prelimi...  4o mini
# 4  The opinion outlines significant criticisms of...  4o mini

# %%
df_4o.head()
# Out:
#         id                                           resource   opinion  \
# 0  1511621  https://www.courtlistener.com/api/rest/v4/opin...  in favor
# 1  9439564  https://www.courtlistener.com/api/rest/v4/opin...   opposed
# 2   781274  https://www.courtlistener.com/api/rest/v4/opin...  in favor
# 3  2453197  https://www.courtlistener.com/api/rest/v4/opin...  in favor
# 4  2312256  https://www.courtlistener.com/api/rest/v4/opin...  in favor
#
#                                          explanation model
# 0  The opinion affirms the constitutionality of t...    4o
# 1  The opinion is a dissenting one, meaning it di...    4o
# 2  The Supreme Court opinion ultimately affirms t...    4o
# 3  The Supreme Court opinion denied Michael Newdo...    4o
# 4  The opinion supports the legality of the U.S. ...    4o

# %%
df_4o_mini['real opinion'] = df_4o_mini['id'].map(decision_dict).map({'For': 'in favor', 'Against': 'opposed'})
df_4o_mini
# Out:
#           id                                           resource   opinion  \
# 0    1511621  https://www.courtlistener.com/api/rest/v4/opin...  in favor
# 1    9439564  https://www.courtlistener.com/api/rest/v4/opin...   opposed
# 2     781274  https://www.courtlistener.com/api/rest/v4/opin...  in favor
# 3    2453197  https://www.courtlistener.com/api/rest/v4/opin...  in favor
# 4    2312256  https://www.courtlistener.com/api/rest/v4/opin...   opposed
# ..       ...                                                ...       ...
# 142  9420604  https://www.courtlistener.com/api/rest/v4/opin...   opposed
# 143   793344  https://www.courtlistener.com/api/rest/v4/opin...  in favor
# 144  4232139  https://www.courtlistener.com/api/rest/v4/opin...   opposed
# 145   784537  https://www.courtlistener.com/api/rest/v4/opin...   opposed
# 146   708223  https://www.courtlistener.com/api/rest/v4/opin...   opposed
#
#                                            explanation    model real opinion
# 0    The court upheld the constitutionality of the ...  4o mini     in favor
# 1    The dissenting opinion expresses strong disagr...  4o mini     in favor
# 2    The court's ruling affirms the dismissal of th...  4o mini     in favor
# 3    The court denied Newdow's motion for a prelimi...  4o mini     in favor
# 4    The opinion outlines significant criticisms of...  4o mini     in favor
# ..                                                 ...      ...          ...
# 142  Justice Reed's opinion expresses disagreement ...  4o mini      opposed
# 143  The majority opinion affirms the President's a...  4o mini      opposed
# 144  The opinion clearly states that the President'...  4o mini      opposed
# 145  The opinion criticizes the actions of the Exec...  4o mini      opposed
# 146  The opinion highlights concerns over the selec...  4o mini      opposed
#
# [147 rows x 6 columns]

# %%
df_4o['real opinion'] = df_4o_mini['id'].map(decision_dict).map({'For': 'in favor', 'Against': 'opposed'})
df_4o
# Out:
#           id                                           resource   opinion  \
# 0    1511621  https://www.courtlistener.com/api/rest/v4/opin...  in favor
# 1    9439564  https://www.courtlistener.com/api/rest/v4/opin...   opposed
# 2     781274  https://www.courtlistener.com/api/rest/v4/opin...  in favor
# 3    2453197  https://www.courtlistener.com/api/rest/v4/opin...  in favor
# 4    2312256  https://www.courtlistener.com/api/rest/v4/opin...  in favor
# ..       ...                                                ...       ...
# 142  9420604  https://www.courtlistener.com/api/rest/v4/opin...   opposed
# 143   793344  https://www.courtlistener.com/api/rest/v4/opin...  in favor
# 144  4232139  https://www.courtlistener.com/api/rest/v4/opin...   opposed
# 145   784537  https://www.courtlistener.com/api/rest/v4/opin...   opposed
# 146   708223  https://www.courtlistener.com/api/rest/v4/opin...   opposed
#
#                                            explanation model real opinion
# 0    The opinion affirms the constitutionality of t...    4o     in favor
# 1    The opinion is a dissenting one, meaning it di...    4o     in favor
# 2    The Supreme Court opinion ultimately affirms t...    4o     in favor
# 3    The Supreme Court opinion denied Michael Newdo...    4o     in favor
# 4    The opinion supports the legality of the U.S. ...    4o     in favor
# ..                                                 ...   ...          ...
# 142  The opinion criticizes the Court's decision to...    4o      opposed
# 143  The opinion affirms the judgment of the Court ...    4o      opposed
# 144  The Supreme Court opinion is primarily opposed...    4o      opposed
# 145  The opinion is opposed to the President's posi...    4o      opposed
# 146  The opinion is opposed to actions taken by the...    4o      opposed
#
# [147 rows x 6 columns]

# %%
from sklearn.metrics import classification_report, accuracy_score

# Same mapping as before
df_4o_test = df_4o
df_4o_test['real opinion'] = df_4o['real opinion'].map({'in favor': 1, 'opposed': 0})
df_4o_test['opinion'] = df_4o['opinion'].map({'in favor': 1, 'opposed': 0})

df_4o_mini_test = df_4o_mini
df_4o_mini_test['real opinion'] = df_4o_mini['real opinion'].map({'in favor': 1, 'opposed': 0})
df_4o_mini_test['opinion'] = df_4o_mini['opinion'].map({'in favor': 1, 'opposed': 0})

y_true_4o = df_4o_test['real opinion']
y_pred_4o = df_4o_test['opinion']
accuracy_4o = accuracy_score(y_true_4o, y_pred_4o)

print(f"\nAccuracy (4o Model): {accuracy_4o:.2f}")
print("ChatGPT 4o Classification Report:")
print(classification_report(y_true_4o, y_pred_4o, labels=[1, 0], 
                          target_names=['in favor', 'opposed']))

y_true_4o_mini = df_4o_mini_test['real opinion']
y_pred_4o_mini = df_4o_mini_test['opinion']
accuracy_4o_mini = accuracy_score(y_true_4o_mini, y_pred_4o_mini)

print(f"Accuracy (4o Mini Model): {accuracy_4o_mini:.2f}")
print("ChatGPT 4o-mini Classification Report:")
print(classification_report(y_true_4o_mini, y_pred_4o_mini, labels=[1, 0], 
                          target_names=['in favor', 'opposed']))
# Out:
# Accuracy (4o Model): 0.74
# ChatGPT 4o Classification Report:
#               precision    recall  f1-score   support
#
#     in favor       0.91      0.70      0.79       104
#      opposed       0.54      0.84      0.65        43
#
#     accuracy                           0.74       147
#    macro avg       0.72      0.77      0.72       147
# weighted avg       0.80      0.74      0.75       147
#
# Accuracy (4o Mini Model): 0.68
# ChatGPT 4o-mini Classification Report:
#               precision    recall  f1-score   support
#
#     in favor       0.93      0.60      0.73       104
#      opposed       0.47      0.88      0.62        43
#
#     accuracy                           0.68       147
#    macro avg       0.70      0.74      0.67       147
# weighted avg       0.79      0.68      0.69       147

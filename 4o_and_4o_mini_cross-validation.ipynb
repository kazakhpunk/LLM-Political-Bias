# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import json

def compress_jsonl(input_file, output_file):
    with open(input_file, 'r') as infile:
        current_json = ""
        for line in infile:
            current_json += line
            try:
                json_obj = json.loads(current_json)
                with open(output_file, 'a') as outfile:
                    outfile.write(json.dumps(json_obj, separators=(',',':')) + '\n')
                current_json = ""
            except json.JSONDecodeError:
                continue
    
compress_jsonl('courts_for_gpt.jsonl', 'compressed_courts_for_comparing.jsonl')

# %%
df = pd.read_json('compressed_courts_for_comparing.jsonl', lines=True)
df
# Out:
#                                            resource_uri       id  \
# 0     https://www.courtlistener.com/api/rest/v4/opin...   103875
# 1     https://www.courtlistener.com/api/rest/v4/opin...  9419386
# 2     https://www.courtlistener.com/api/rest/v4/opin...  9419387
# 3     https://www.courtlistener.com/api/rest/v4/opin...  9419388
# 4     https://www.courtlistener.com/api/rest/v4/opin...  9419389
# ...                                                 ...      ...
# 1317  https://www.courtlistener.com/api/rest/v4/opin...   111375
# 1318  https://www.courtlistener.com/api/rest/v4/opin...  9429952
# 1319  https://www.courtlistener.com/api/rest/v4/opin...  9429953
# 1320  https://www.courtlistener.com/api/rest/v4/opin...   325463
# 1321  https://www.courtlistener.com/api/rest/v4/opin...   778317
#
#                                            absolute_url  cluster_id  \
# 0          /opinion/103875/hirabayashi-v-united-states/      103875
# 1          /opinion/103875/hirabayashi-v-united-states/      103875
# 2          /opinion/103875/hirabayashi-v-united-states/      103875
# 3          /opinion/103875/hirabayashi-v-united-states/      103875
# 4          /opinion/103875/hirabayashi-v-united-states/      103875
# ...                                                 ...         ...
# 1317             /opinion/111375/wayte-v-united-states/      111375
# 1318             /opinion/111375/wayte-v-united-states/      111375
# 1319             /opinion/111375/wayte-v-united-states/      111375
# 1320  /opinion/325463/edward-m-kennedy-v-arthur-f-sa...      325463
# 1321  /opinion/778317/yaser-esam-hamdi-esam-fouad-ha...      778317
#
#                                                 cluster  author_id  \
# 0     https://www.courtlistener.com/api/rest/v4/clus...     3115.0
# 1     https://www.courtlistener.com/api/rest/v4/clus...        NaN
# 2     https://www.courtlistener.com/api/rest/v4/clus...        NaN
# 3     https://www.courtlistener.com/api/rest/v4/clus...        NaN
# 4     https://www.courtlistener.com/api/rest/v4/clus...        NaN
# ...                                                 ...        ...
# 1317  https://www.courtlistener.com/api/rest/v4/clus...     2611.0
# 1318  https://www.courtlistener.com/api/rest/v4/clus...        NaN
# 1319  https://www.courtlistener.com/api/rest/v4/clus...        NaN
# 1320  https://www.courtlistener.com/api/rest/v4/clus...        NaN
# 1321  https://www.courtlistener.com/api/rest/v4/clus...        NaN
#
#                                                  author joined_by  \
# 0     https://www.courtlistener.com/api/rest/v4/peop...        []
# 1                                                  None        []
# 2                                                  None        []
# 3                                                  None        []
# 4                                                  None        []
# ...                                                 ...       ...
# 1317  https://www.courtlistener.com/api/rest/v4/peop...        []
# 1318                                               None        []
# 1319                                               None        []
# 1320                                               None        []
# 1321                                               None        []
#
#                           date_created                     date_modified  ...  \
# 0            2010-04-28T09:54:39-07:00  2022-03-07T14:04:30.030299-08:00  ...
# 1     2023-08-02T15:49:12.921336-07:00  2024-09-05T09:19:04.336904-07:00  ...
# 2     2023-08-02T15:49:12.925749-07:00  2024-09-05T09:19:04.343347-07:00  ...
# 3     2023-08-02T15:49:12.928835-07:00  2024-09-05T09:19:04.347692-07:00  ...
# 4     2023-08-02T15:49:12.931232-07:00  2024-09-05T09:19:04.351779-07:00  ...
# ...                                ...                               ...  ...
# 1317         2010-04-28T10:13:11-07:00  2020-02-21T14:20:41.851606-08:00  ...
# 1318  2023-08-02T16:28:25.101205-07:00  2024-09-05T09:27:34.598379-07:00  ...
# 1319  2023-08-02T16:28:25.107688-07:00  2024-09-05T09:27:34.604233-07:00  ...
# 1320         2011-08-23T01:57:09-07:00  2023-08-04T15:16:01.015475-07:00  ...
# 1321         2012-04-18T06:00:27-07:00  2023-08-05T08:56:17.369629-07:00  ...
#
#      plain_text                                               html  \
# 0                <p class="case_cite">320 U.S. 81</p>\n    <p c...
# 1
# 2
# 3
# 4
# ...         ...                                                ...
# 1317             <p class="case_cite">470 U.S. 598</p>\n    <p ...
# 1318
# 1319
# 1320             <p class="case_cite">511 F.2d 430</p>\n    <p ...
# 1321             <p class="case_cite">296 F.3d 278</p>\n    <p ...
#
#                                             html_lawbox html_columbia  \
# 0     <div>\n<center><b>320 U.S. 81 (1943)</b></cent...
# 1
# 2
# 3
# 4
# ...                                                 ...           ...
# 1317  <div>\n<center><b>470 U.S. 598 (1985)</b></cen...
# 1318
# 1319
# 1320
# 1321
#
#      html_anon_2020                                        xml_harvard  \
# 0
# 1                    <opinion type="majority">\n<author id="b149-3"...
# 2                    <opinion type="concurrence">\n<author id="b171...
# 3                    <opinion type="concurrence">\n<author id="b175...
# 4                    <opinion type="concurrence">\n<author id="b180...
# ...             ...                                                ...
# 1317
# 1318                 <opinion type="majority">\n<author id="AFF1">J...
# 1319                 <opinion type="dissent">\n<author id="b670-8">...
# 1320                 <?xml version="1.0" encoding="utf-8"?>\n<opini...
# 1321                 <?xml version="1.0" encoding="utf-8"?>\n<opini...
#
#                                     html_with_citations extracted_by_ocr  \
# 0     <div>\n<center><b><span class="citation no-lin...            False
# 1                                                                  False
# 2                                                                  False
# 3                                                                  False
# 4                                                                  False
# ...                                                 ...              ...
# 1317  <div>\n<center><b><span class="citation no-lin...            False
# 1318                                                               False
# 1319                                                               False
# 1320  <p class="case_cite"><span class="citation no-...            False
# 1321  <p class="case_cite"><span class="citation no-...            False
#
#      ordering_key                                     opinions_cited
# 0             NaN  [https://www.courtlistener.com/api/rest/v4/opi...
# 1             1.0                                                 []
# 2             2.0                                                 []
# 3             3.0                                                 []
# 4             4.0                                                 []
# ...           ...                                                ...
# 1317          NaN  [https://www.courtlistener.com/api/rest/v4/opi...
# 1318          1.0                                                 []
# 1319          2.0                                                 []
# 1320          NaN  [https://www.courtlistener.com/api/rest/v4/opi...
# 1321          NaN  [https://www.courtlistener.com/api/rest/v4/opi...
#
# [1322 rows x 28 columns]

# %%
((df == "") | df.isnull()).sum().sort_values(ascending=False)
# Out:
# html_anon_2020         1322
# joined_by_str          1322
# html_columbia          1322
# page_count             1093
# plain_text             1091
# local_path             1091
# author_id              1013
# author                 1013
# html                    998
# html_lawbox             966
# download_url            908
# ordering_key            731
# html_with_citations     591
# sha1                    591
# author_str              440
# xml_harvard             431
# extracted_by_ocr          0
# resource_uri              0
# id                        0
# type                      0
# per_curiam                0
# date_modified             0
# date_created              0
# joined_by                 0
# cluster                   0
# cluster_id                0
# absolute_url              0
# opinions_cited            0
# dtype: int64

# %%
import json

def create_batch_4o_mini(custom_id, method, url, messages, output_file):
    batch_entry = {
        "custom_id": custom_id,
        "method": method,
        "url": url,
        "body": {
            "model": "gpt-4o-mini",
            "messages": messages,
            "max_tokens": 9000
        }
    }
    with open(output_file, 'a') as outfile:
        outfile.write(json.dumps(batch_entry, separators=(',',':')) + '\n')

def create_batch_4o(custom_id, method, url, messages, output_file):
    batch_entry = {
        "custom_id": custom_id,
        "method": method,
        "url": url,
        "body": {
            "model": "gpt-4o",
            "messages": messages,
            "max_tokens": 9000
        }
    }
    with open(output_file, 'a') as outfile:
        outfile.write(json.dumps(batch_entry, separators=(',',':')) + '\n')
        
output_file_4o_mini = 'batch_input_4o_mini.jsonl'
output_file_4o = 'batch_input_4o.jsonl'
method = "POST"
url = "/v1/chat/completions"

line_count = 0
for index, row in df.iterrows():
    if line_count >= 100:  # Limit to first 100 lines
        break
    valid_column = next(
        (col for col in ['html', 'xml_harvard', 'plain_text', 'html_lawbox'] if pd.notnull(row[col]) and row[col] != ""), 
        None
    )

    custom_id = f"request-{index + 1}"
    messages = [
    {
        "role": "system", 
        "content": "Your goal is to determine whether each opinion is in favor of or opposing the President. You will receive the text of a Supreme Court opinion, and you should analyze the sentiment and key phrases to make your determination."
    },
    {
        "role": "user", 
        "content": f"""Here is the text of a Supreme Court opinion: {row[valid_column]}.
        Based on this opinion, please analyze the sentiment and determine if it is in favor of or opposing the President. 
        Return your response in JSON format:
            {{
                "resource": "{row['resource_uri']}",
                "opinion": "with values 'in favor' or 'opposed'",
                "explanation": "a brief explanation of your conclusion"
            }}
        """
    }
]

    create_batch_4o_mini(custom_id, method, url, messages, output_file_4o_mini)
    create_batch_4o(custom_id, method, url, messages, output_file_4o)
    line_count += 1  # Increment line count

# %%
import os

def test_4o_mini(input_file, output_files):
    with open(input_file, 'r') as infile:
        line_count = 0 
        for line in infile:
            if line_count >= 100: 
                break
            try:
                json_obj = json.loads(line)
                output_index = line_count // 25
                os.makedirs(os.path.dirname(output_files[output_index]), exist_ok=True)
                with open(output_files[output_index], 'a') as outfile:
                    outfile.write(json.dumps(json_obj) + '\n')
            except json.JSONDecodeError:
                continue
            line_count += 1  

output_files = ['4o_mini/1_mini.jsonl', '4o_mini/2_mini.jsonl', '4o_mini/3_mini.jsonl', '4o_mini/4_mini.jsonl']
test_4o_mini('batch_input.jsonl', output_files)

def test_4o(input_file, output_files):
    with open(input_file, 'r') as infile:
        line_count = 0 
        for line in infile:
            if line_count >= 100: 
                break
            try:
                json_obj = json.loads(line)
                output_index = line_count // 10
                os.makedirs(os.path.dirname(output_files[output_index]), exist_ok=True)
                with open(output_files[output_index], 'a') as outfile:
                    outfile.write(json.dumps(json_obj) + '\n')
            except json.JSONDecodeError:
                continue
            line_count += 1  

output_files = ['4o/1.jsonl', '4o/2.jsonl', '4o/3.jsonl', '4o/4.jsonl', '4o/5.jsonl', '4o/6.jsonl', '4o/7.jsonl', '4o/8.jsonl', '4o/9.jsonl', '4o/10.jsonl']
test_4o('batch_input.jsonl', output_files)

# %%
from dotenv import load_dotenv
load_dotenv()

from openai import OpenAI
client = OpenAI()

def process_files(files_to_process, file_ids, batch_ids):
    for file in files_to_process:
        batch_input_file = client.files.create(
          file=open(file, "rb"),
          purpose="batch"
        )

        batch_input_file_id = batch_input_file.id
        file_ids.append(batch_input_file_id)

        batch = client.batches.create(
            input_file_id=batch_input_file_id,
            endpoint="/v1/chat/completions",
            completion_window="24h",
            metadata={
              "description": f"test job for {file}"
            }
        )
        batch_ids.append(batch.id)

files_to_process_4o = ['4o/1.jsonl', '4o/2.jsonl', '4o/3.jsonl', '4o/4.jsonl', '4o/5.jsonl', '4o/6.jsonl', '4o/7.jsonl', '4o/8.jsonl', '4o/9.jsonl', '4o/10.jsonl']
file_ids_4o = []
batch_ids_4o = []
process_files(files_to_process_4o, file_ids_4o, batch_ids_4o)

files_to_process_4o_mini = ['4o_mini/1_mini.jsonl', '4o_mini/2_mini.jsonl', '4o_mini/3_mini.jsonl', '4o_mini/4_mini.jsonl']
file_ids_4o_mini = []
batch_ids_4o_mini = []
process_files(files_to_process_4o_mini, file_ids_4o_mini, batch_ids_4o_mini)

# %%
def check_batch(batch_ids):
    res = {}
    for batch_id in batch_ids:
        try:
            print(client.batches.retrieve(batch_id))
        except Exception as e:
            print(f"Error retrieving status: {e}")
    
check_batch(batch_ids_4o_mini)
# Out:
# Batch(id='batch_671ce806cce88190a8c213a73c2fe5b9', completion_window='24h', created_at=1729947654, endpoint='/v1/chat/completions', input_file_id='file-bMVdzq6ZZ7hX577yiwbnqNEb', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1729947721, error_file_id=None, errors=None, expired_at=None, expires_at=1730034054, failed_at=None, finalizing_at=1729947718, in_progress_at=1729947655, metadata={'description': 'test job for 4o_mini/1_mini.jsonl'}, output_file_id='file-hc79YlQGjij04A8TYn7KSGJq', request_counts=BatchRequestCounts(completed=25, failed=0, total=25))
# Batch(id='batch_671ce80979348190a75a96da5b090349', completion_window='24h', created_at=1729947657, endpoint='/v1/chat/completions', input_file_id='file-1EbDB87k7IjrCxhIeQS6UOzh', object='batch', status='failed', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=Errors(data=[BatchError(code='token_limit_exceeded', line=None, message='Enqueued token limit reached for gpt-4o-mini in organization org-A18GXBrG1KMVVOoyVorIIeER. Limit: 2,000,000 enqueued tokens. Please try again once some in_progress batches have been completed.', param=None)], object='list'), expired_at=None, expires_at=1730034057, failed_at=1729947658, finalizing_at=None, in_progress_at=None, metadata={'description': 'test job for 4o_mini/2_mini.jsonl'}, output_file_id=None, request_counts=BatchRequestCounts(completed=0, failed=0, total=0))
# Batch(id='batch_671ce80ac8e4819084fb2aaa0248790d', completion_window='24h', created_at=1729947658, endpoint='/v1/chat/completions', input_file_id='file-tDwPHmqshmAW71mJq51yQqrk', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1729947712, error_file_id=None, errors=None, expired_at=None, expires_at=1730034058, failed_at=None, finalizing_at=1729947709, in_progress_at=1729947659, metadata={'description': 'test job for 4o_mini/3_mini.jsonl'}, output_file_id='file-PZfH7pXKDR0CTn41hpT81IJF', request_counts=BatchRequestCounts(completed=25, failed=0, total=25))
# Batch(id='batch_671ce80c79288190a8578bbd95666caf', completion_window='24h', created_at=1729947660, endpoint='/v1/chat/completions', input_file_id='file-67LYPLnPa50f0bPpo10jA7gG', object='batch', status='failed', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=Errors(data=[BatchError(code='token_limit_exceeded', line=None, message='Enqueued token limit reached for gpt-4o-mini in organization org-A18GXBrG1KMVVOoyVorIIeER. Limit: 2,000,000 enqueued tokens. Please try again once some in_progress batches have been completed.', param=None)], object='list'), expired_at=None, expires_at=1730034060, failed_at=1729947660, finalizing_at=None, in_progress_at=None, metadata={'description': 'test job for 4o_mini/4_mini.jsonl'}, output_file_id=None, request_counts=BatchRequestCounts(completed=0, failed=0, total=0))

# %%
import json

def content_jsonl(input_file, output_file):
            with open(input_file, 'r') as infile:
                for line in infile:
                    try:
                        json_obj = json.loads(line) 
                        content = json_obj.get('response', {}).get('body', {}).get('choices', [{}])[0].get('message', {}).get('content', '') 
                        with open(output_file, 'a') as outfile:
                            outfile.write(json.dumps(content) + '\n')
                    except json.JSONDecodeError:
                        continue

def retrieve_batches(batch_ids, output_jsonl_file, content_output_file):
    for batch_id in batch_ids:
        batch_info = client.batches.retrieve(batch_id)

        input_file_response = client.files.content(batch_info.output_file_id)

        for line in input_file_response.text.splitlines():
            try:
                json_obj = json.loads(line)  
                with open(output_jsonl_file, 'a') as outfile:
                    outfile.write(json.dumps(json_obj) + '\n')  
            except json.JSONDecodeError:
                continue
    content_jsonl(output_jsonl_file, content_output_file)

retrieve_batches(batch_ids_4o_mini, 'response_test_4o_mini.jsonl', 'content_test_4o_mini.jsonl')
retrieve_batches(batch_ids_4o, 'response_test_4o.jsonl', 'content_test_4o.jsonl')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 29
#      26                 continue
#      27     content_jsonl(output_jsonl_file, content_output_file)
# ---> 29 retrieve_batches(batch_ids_4o_mini, 'response_test_4o_mini.jsonl', 'content_test_4o_mini.jsonl')
#      30 retrieve_batches(batch_ids_4o, 'response_test_4o.jsonl', 'content_test_4o.jsonl')
#
# Cell In[17], line 18, in retrieve_batches(batch_ids, output_jsonl_file, content_output_file)
#      15 for batch_id in batch_ids:
#      16     batch_info = client.batches.retrieve(batch_id)
# ---> 18     input_file_response = client.files.content(batch_info.output_file_id)
#      20     for line in input_file_response.text.splitlines():
#      21         try:
#
# File ~/miniconda3/envs/SRA/lib/python3.12/site-packages/openai/resources/files.py:256, in Files.content(self, file_id, extra_headers, extra_query, extra_body, timeout)
#     243 """
#     244 Returns the contents of the specified file.
#     245
#    (...)
#     253   timeout: Override the client-level default timeout for this request, in seconds
#     254 """
#     255 if not file_id:
# --> 256     raise ValueError(f"Expected a non-empty value for `file_id` but received {file_id!r}")
#     257 extra_headers = {"Accept": "application/binary", **(extra_headers or {})}
#     258 return self._get(
#     259     f"/files/{file_id}/content",
#     260     options=make_request_options(
#    (...)
#     263     cast_to=_legacy_response.HttpxBinaryResponseContent,
#     264 )
#
# ValueError: Expected a non-empty value for `file_id` but received None

# %%
import json
import re

def clean_json(input_file, output_file):
    with open(input_file, 'r') as infile, open(output_file, 'w') as outfile:
        for line_number, line in enumerate(infile, start=1):
            line = line.strip()
            
            if not line:
                continue
            
            if line.startswith('"```json\\n') and line.endswith('```"'):
                line = line[10:-3].strip()
            
            line = line.replace('\\"', '"').replace('\\n', '')[:-1]

            if line.startswith('"'):
                line = line[1:]
            
            line = re.sub(r'\s+(?=(?:[^"]|"[^"]*")*$)', '', line)
            
            try:
                json_obj = json.loads(line)
                outfile.write(json.dumps(json_obj) + '\n')
            except json.JSONDecodeError as e:
                continue

# Usage
clean_json('content_test_4o_mini.jsonl', 'cleaned_content_test_4o_mini.jsonl')
clean_json('content_test_4o.jsonl', 'cleaned_content_test_4o.jsonl')
